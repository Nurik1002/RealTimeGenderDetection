# %%
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from keras.utils import image_dataset_from_directory
from keras.models import Model, Sequential
import matplotlib.pyplot as plt
import numpy as np

# %%
train_data = image_dataset_from_directory("Data/Training/", batch_size=8, image_size=(224,224))
# Out:
# Found 47009 files belonging to 2 classes.

# %%
valid_data = image_dataset_from_directory("Data/Validation/", batch_size=8,image_size=(224,224))
# Out:
# Found 11649 files belonging to 2 classes.

# %%
print("Train data : ")
CLASSES = train_data.class_names
for rasm,label in train_data.take(1):
    for i in range(8):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(rasm[i].numpy().astype("uint8"))
        plt.title(CLASSES[label[i]])
        
plt.show()
# Out:
# Train data :
# 2023-03-14 18:49:19.775352: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [47009]
# 	 [[{{node Placeholder/_4}}]]
# 2023-03-14 18:49:19.776666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [47009]
# 	 [[{{node Placeholder/_4}}]]

# %%
print("Validation data : ")
CLASSES = valid_data.class_names
for rasm,label in valid_data.take(1):
    for i in range(8):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(rasm[i].numpy().astype("uint8"))
        plt.title(CLASSES[label[i]])
        
plt.show()
# Out:
# Validation data :
# 2023-03-14 18:50:35.790058: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype string and shape [11649]
# 	 [[{{node Placeholder/_0}}]]
# 2023-03-14 18:50:35.791105: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_4' with dtype int32 and shape [11649]
# 	 [[{{node Placeholder/_4}}]]
