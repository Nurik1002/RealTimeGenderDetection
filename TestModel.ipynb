# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cvlib
import cv2

# %%
model = tf.keras.models.load_model("model.h5")
pred = ['female', 'male']

# %%
img1 = cv2.imread("images/test1.jpg")
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img1_copy = img1.copy()
plt.imshow(img1)
plt.show()

# %%
faces1  = []
faces1_1 = []
for x1,y1,x2,y2 in face1[0]:
    cv2.rectangle(img1_copy,(x1-10,y1-10),(x2+10,y2+10),(255,0,0),3)
    faces1.append(img1[y1-10:y2+10, x1-10:x2+10])
    faces1_1.append(img1[y1-10:y2+10, x1-10:x2+10])
    
plt.imshow(img1_copy)
plt.show()

for i in range(len(faces1)):
    faces1[i] = cv2.resize(faces1[i], (224,224))
    faces1[i] = np.expand_dims(faces1[i], 0)

# %%
i = 1
print("Prediction image : ")

natija = np.argmax(model.predict(faces1[i]))
plt.imshow(faces1_1[i])
plt.title(pred[natija])
plt.show()
# Out:
# Prediction image :
# 1/1 [==============================] - 0s 17ms/step

# %%
model.predict(faces1[1])
# Out:
# 1/1 [==============================] - 0s 108ms/step
# array([[0.51501054]], dtype=float32)

# %%
img2 = cv2.imread("images/test2.jpeg")
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img2_copy = img2.copy()
plt.imshow(img2)
plt.show()

# %%
face2 = cvlib.detect_face(img2)
face2
# Out:
# ([[115, 10, 132, 33], [165, 21, 182, 46], [70, 35, 90, 61]],
#  [0.9530262, 0.9171479, 0.895092])

# %%
faces2 = []
faces2_1 = []

for x1,y1,x2,y2 in face2[0]:
    cv2.rectangle(img2_copy,(x1,y1),(x2,y2),(255,0,0))
    faces2.append(img2[y1:y2, x1:x2])
    faces2_1.append(img2[y1:y2, x1:x2])
    
plt.imshow(img2_copy)
plt.show()

for i in range(len(faces2)):
    faces2[i] = cv2.resize(faces2[i], (224,224))
    faces2[i] = np.expand_dims(faces2[i], 0)

# %%
i = 2

natija = np.argmax(model.predict(faces2[i]))
plt.imshow(faces2_1[i])
plt.title(pred[natija])
plt.show()
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
img3 = cv2.imread("images/test3.jpg")
img3 = cv2.cvtColor(img3, cv2.COLOR_BGR2RGB)
img3_copy = img3.copy()
plt.imshow(img3)
plt.show()

# %%
face3 = cvlib.detect_face(img3)
face3
# Out:
# ([[99, 32, 144, 89],
#   [390, 62, 438, 122],
#   [234, 66, 274, 121],
#   [486, 59, 529, 115],
#   [54, 71, 98, 127],
#   [331, 83, 373, 132],
#   [171, 84, 212, 136]],
#  [0.99666363,
#   0.99289674,
#   0.9904841,
#   0.9865324,
#   0.9864775,
#   0.98380035,
#   0.97908944])

# %%
faces3 = []
faces3_1 = []

for x1,y1,x2,y2 in face3[0]:    
    faces3.append(img3[y1-10:y2+10, x1-10:x2+10] )
    faces31.append(img3[y1-10:y2+10, x1-10:x2+10])
    cv2.rectangle(img3_copy,(x1-10,y1-10),(x2+10,y2+10),(255,0,0),3)
    
    
plt.imshow(img3_copy)
plt.show()

for i in range(len(faces3)):
    faces3[i] = cv2.resize(faces3[i], (224,224))
    faces3[i] = np.expand_dims(faces3[i], 0)

# %%
i = 5

natija = np.argmax(model_drop.predict(faces3[i]))
plt.imshow(faces3_1[i])
plt.title(pred[natija])
plt.show()
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %% [markdown]
# #
